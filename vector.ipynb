# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.set()

# %% [markdown]
# Vector Addition if we have 2 vectors [2,3],[3,-2] then their addition will be [5,1] and subtraction will be [-1,5]. Visualizing them we get:

# %%
plt.quiver(0, 0, 2, 3, angles='xy', scale_units='xy', scale=1, color='r')
plt.quiver(0, 0, 3, -2, angles='xy', scale_units='xy', scale=1, color='r') 

plt.xlim(-3, 6)
plt.ylim(-3, 6)
plt.show()

# %% [markdown]
# ADDITION

# %%
plt.quiver(0, 0, 2, 3, angles='xy', scale_units='xy', scale=1, color='r')
plt.quiver(0, 0, 3, -2, angles='xy', scale_units='xy', scale=1, color='r') 
plt.quiver(0, 0, 5, 1, angles='xy', scale_units='xy', scale=1, color='b') #addition

plt.xlim(-3, 6)
plt.ylim(-3, 6)
plt.show()

# %%
vector_1=np.asarray([0,0,2,3])
vector_2=np.asarray([0,0,3,-2])
sum = vector_1+vector_2
print(sum)
# Out:
# [0 0 5 1]

# %% [markdown]
# Subtraction

# %%
plt.quiver(0, 0, 2, 3, angles='xy', scale_units='xy', scale=1, color='r')
plt.quiver(0, 0, 3, -2, angles='xy', scale_units='xy', scale=1, color='r') 
plt.quiver(0, 0, -1, 5, angles='xy', scale_units='xy', scale=1, color='g') #subtraction

plt.xlim(-3, 6)
plt.ylim(-3, 6)
plt.show()

# %%
vector_1=np.asarray([0,0,2,3])
vector_2=np.asarray([0,0,3,-2])
subtraction = vector_1-vector_2
print(subtraction)
# Out:
# [ 0  0 -1  5]

# %% [markdown]
# Multiplying

# %%
v1= np.asarray([0,0,2,3])
result= 2*v1
print(result)
# Out:
# [0 0 4 6]

# %%
plt.quiver(0,0,2,3, angles='xy',scale_units='xy',scale=1,color='r')
plt.quiver(0,0,4,6,angles='xy',scale_units='xy',scale=1,color='g')
plt.xlim(-1,10)
plt.ylim(-1,10)
plt.show()

# %%
v1=np.asarray([0,0,2,3])
res=-0.5*v1
print(res)
# Out:
# [-0.  -0.  -1.  -1.5]

# %%
plt.quiver(0,0,2,3,angles='xy',scale_units='xy',scale=1,color='r')
plt.quiver(0,0,-1,-1.5,angles='xy',scale_units='xy',scale=1,color='y')
plt.xlim(-5,6)
plt.ylim(-5,6)
plt.show()
